# %%
#Code for making basic map

import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import numpy as np
import pandas as pd
import datetime as dt

water = pd.read_csv("water_usage_edit.csv")
power = pd.read_csv("elec_usage_edit.csv")
weather = pd.read_csv("weather_data_edit.csv", encoding="latin1")

# %%
#water

x2 = np.array([228, 211, 219])
y2 = np.array([1180, 1879, 1858])

plt.plot(y2, x2)


plt.show()

# %%
#power
# Out:
#                       Date  Usage(kWh)
# 0      21/10/2013 00:00:00         975
# 1      22/10/2013 00:00:00        1880
# 2      23/10/2013 00:00:00        1879
# 3      24/10/2013 00:00:00        1858
# 4      25/10/2013 00:00:00        1896
# ...                    ...         ...
# 3275   24/09/2022 00:00:00        1062
# 3276   25/09/2022 00:00:00         766
# 3277   26/09/2022 00:00:00         769
# 3278   27/09/2022 00:00:00        1602
# 3279   28/09/2022 00:00:00        1655
#
# [3280 rows x 2 columns]

# %%
x1 = np.array([0,1,2,3,4])
y1 = np.array([975,1880,1879,1858,1896])

plt.plot(x1,y1)
plt.show()

# %%
weather.plot()
# Out:
# <AxesSubplot:>

# %%
power.plot()
# Out:
# <AxesSubplot:>

# %%
water.plot()
# Out:
# <AxesSubplot:>

# %%
#weather
filtered_weather = weather.loc[(weather['Date'] >= '2013/10/21') & (weather['Date'] <= '2022/08/31')]
filtered_weather
# Out:
# Empty DataFrame
# Columns: [Date, Rainfall (mm), Max Temp (°C), Min Temp (°C)]
# Index: []

# %%
test = weather.plot(x='Date', y='Rainfall (mm)')

# %%
x1 = power[]
